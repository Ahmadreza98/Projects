# %% [markdown]
# # HOW TO USE NUMPY?
# ## Part - 4

# %%
import numpy as np

# %% [markdown]
# Extra explain about **Matrix Multiple**.

# %%
A = np.array([[1,2,3],[7,8,9]])
B = np.array([[4,5],[6,7],[8,9]])

# %% [markdown]
# To display the dimensions of a matrix

# %%
A.shape
# Out:
# (2, 3)

# %%
B.shape
# Out:
# (3, 2)

# %%
A @ B
# Out:
# array([[ 40,  46],
#        [148, 172]])

# %%
(A@B).shape
# Out:
# (2, 2)

# %% [markdown]
# **SUM** operation array of cells.

# %%
print(np.sum(A))
# Out:
# 30

# %%
print(np.sum(A, axis=0))
# Out:
# [ 8 10 12]

# %%
print(np.sum(A, axis=1))
# Out:
# [ 6 24]
