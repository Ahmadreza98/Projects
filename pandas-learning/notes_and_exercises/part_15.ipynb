# %% [markdown]
# # How to use Pandas?
# ## Part - 15

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Read** and **Save** data with format **CSV** in **Pandas**

# %%
exam_df = pd.read_csv('DATA/example.csv', index_col=[0])

# %%
exam_df
# Out:
#    B   C   D
# A
# 0  4   8  12
# 1  5   9  13
# 2  6  10  14
# 3  7  11  15

# %%
exam_df.to_csv('DATA/new_example.csv')
