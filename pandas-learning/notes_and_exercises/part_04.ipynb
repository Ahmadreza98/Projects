# %% [markdown]
# # How to use Pandas?
# ## Part - 4

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Student Name': ['Ali', 'Maryam', 'Reza', 'Sara', 'Amir', 'Zahra', 'Hossein', 'Fatemeh'],
    'Subject': ['Math', 'Physics', 'Chemistry', 'Math', 'Physics', 'Chemistry', 'Math', 'Physics'],
    'Grade': [18, 15, 19, 17, 14, 16, 20, 13],
    'Status': ['Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass']
}

df = pd.DataFrame(data)

# %% [markdown]
# In the following, we will discuss the process of accessing data and also changing it.

# %% [markdown]
# **Access** to **Rows** in a **DataFrame**

# %%
df.loc[1:3]
# Out:
#   Student Name    Subject  Grade Status
# 1       Maryam    Physics     15   Pass
# 2         Reza  Chemistry     19   Pass
# 3         Sara       Math     17   Pass

# %% [markdown]
# **Add** a **Column** in a **DataFrame**

# %%
df["GRE"] = [4,3,4,4,3,4,5,2]

# %%
df
# Out:
#   Student Name    Subject  Grade Status  GRE
# 0          Ali       Math     18   Pass    4
# 1       Maryam    Physics     15   Pass    3
# 2         Reza  Chemistry     19   Pass    4
# 3         Sara       Math     17   Pass    4
# 4         Amir    Physics     14   Pass    3
# 5        Zahra  Chemistry     16   Pass    4
# 6      Hossein       Math     20   Pass    5
# 7      Fatemeh    Physics     13   Pass    2

# %% [markdown]
# Show **General Information** of **DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Student Name  8 non-null      str
#  1   Subject       8 non-null      str
#  2   Grade         8 non-null      int64
#  3   Status        8 non-null      str
#  4   GRE           8 non-null      int64
# dtypes: int64(2), str(3)
# memory usage: 452.0 bytes

# %% [markdown]
# Also, The ability to **Separate** also exists.

# %%
df[2:4]
# Out:
#   Student Name    Subject  Grade Status  GRE
# 2         Reza  Chemistry     19   Pass    4
# 3         Sara       Math     17   Pass    4

# %%
df.loc[0:2]
# Out:
#   Student Name    Subject  Grade Status  GRE
# 0          Ali       Math     18   Pass    4
# 1       Maryam    Physics     15   Pass    3
# 2         Reza  Chemistry     19   Pass    4

# %%
df.iloc[2]['Grade']
# Out:
# np.int64(19)

# %%
df.iloc[:,4]
# Out:
# 0    4
# 1    3
# 2    4
# 3    4
# 4    3
# 5    4
# 6    5
# 7    2
# Name: GRE, dtype: int64

# %% [markdown]
# **Essential** functions for **deleting** a **Column** or **Row**
#
# For drop a Rows `axis=0` default.
#
# For drop a column `axis=1`.

# %%
df_test.drop('GRE', axis=1)
# Out:
#   Student Name    Subject  Grade Status
# 0          Ali       Math     18   Pass
# 1       Maryam    Physics     15   Pass
# 2         Reza  Chemistry     19   Pass
# 3         Sara       Math     17   Pass
# 4         Amir    Physics     14   Pass
# 5        Zahra  Chemistry     16   Pass
# 6      Hossein       Math     20   Pass
# 7      Fatemeh    Physics     13   Pass

# %%
df_test.drop(2, axis=0)
# Out:
#   Student Name    Subject  Grade Status  GRE
# 0          Ali       Math     18   Pass    4
# 1       Maryam    Physics     15   Pass    3
# 3         Sara       Math     17   Pass    4
# 4         Amir    Physics     14   Pass    3
# 5        Zahra  Chemistry     16   Pass    4
# 6      Hossein       Math     20   Pass    5
# 7      Fatemeh    Physics     13   Pass    2

# %%
df['Sex'] = ["Male","Female","Male","Female","Male", "Female", "Male","Female"]

# %% [markdown]
# Data can be **Replaced**

# %%
df.replace("Male",'M',inplace=True)
df.replace("Female", 'F', inplace=True)
# Out:
#   Student Name    Subject  Grade Status  GRE Sex
# 0          Ali       Math     18   Pass    4   M
# 1       Maryam    Physics     15   Pass    3   F
# 2         Reza  Chemistry     19   Pass    4   M
# 3         Sara       Math     17   Pass    4   F
# 4         Amir    Physics     14   Pass    3   M
# 5        Zahra  Chemistry     16   Pass    4   F
# 6      Hossein       Math     20   Pass    5   M
# 7      Fatemeh    Physics     13   Pass    2   F
