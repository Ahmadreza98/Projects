# %% [markdown]
# # How to use Pandas?
# ## Part - 6

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# One of the features of the Pandas library is its ability to read various types of data in Python.
#
# Now, we want to upload `DATA\Tips.csv`.

# %%
tips_df = pd.read_csv("DATA/tips.csv", sep=',')

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
tips_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    str
#  3   smoker            244 non-null    str
#  4   day               244 non-null    str
#  5   time              244 non-null    str
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    str
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    str
# dtypes: float64(3), int64(2), str(6)
# memory usage: 21.1 KB

# %%
tips_df.describe().T
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# Show to **Colunms** in **DataFrame**

# %%
tips_df[['total_bill', 'tip']].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
tips_df["Total_pay"] = tips_df["total_bill"] + tips_df["tip"]

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  Total_pay
# 0  Christy Cunningham  3560325168603410    Sun2959      18.00
# 1      Douglas Tucker  4478071379779230    Sun4608      12.00
# 2      Travis Walters  6011812112971322    Sun4458      24.51
# 3    Nathaniel Harris  4676137647685994    Sun5260      26.99
# 4        Tonya Carter  4832732618637221    Sun2251      28.20

# %%
tips_df['tip-%'] = np.round(tips_df['tip']/tips_df['Total_pay'] * 100, 2)

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  Total_pay  tip-%
# 0  Christy Cunningham  3560325168603410    Sun2959      18.00   5.61
# 1      Douglas Tucker  4478071379779230    Sun4608      12.00  13.83
# 2      Travis Walters  6011812112971322    Sun4458      24.51  14.28
# 3    Nathaniel Harris  4676137647685994    Sun5260      26.99  12.26
# 4        Tonya Carter  4832732618637221    Sun2251      28.20  12.80
