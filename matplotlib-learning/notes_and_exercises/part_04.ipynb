# %% [markdown]
# # How to use Matplotlib
# ## Part - 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Customer_1 = [800, 538, 224, 531, 492, 214, 490, 645, 412, 671, 748, 307]
Customer_2 = [340, 395, 483, 716, 411, 383, 133, 583, 670, 241, 495, 708]
Customer_3 = [429, 280, 541, 688, 729, 100, 236, 641, 382, 705, 204, 305]

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %% [markdown]
# To show a figure of **Histogram** as follow:

# %%
plt.hist(Customer_1, bins=9)
# Out:
# (array([2., 1., 0., 1., 4., 0., 1., 1., 2.]),
#  array([214.        , 279.11111111, 344.22222222, 409.33333333,
#         474.44444444, 539.55555556, 604.66666667, 669.77777778,
#         734.88888889, 800.        ]),
#  <BarContainer object of 9 artists>)

# %% [markdown]
# To show a figure of **Boxplot** as follow:

# %%
plt.boxplot([Customer_1, Customer_2])
plt.show()
