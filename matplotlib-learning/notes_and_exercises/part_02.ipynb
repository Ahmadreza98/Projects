# %% [markdown]
# # How to use Matplotlib?
# ## Part - 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Customer_1 = [800, 538, 224, 531, 492, 214, 490, 645, 412, 671, 748, 307]
Customer_2 = [340, 395, 483, 716, 411, 383, 133, 583, 670, 241, 495, 708]
Customer_3 = [429, 280, 541, 688, 729, 100, 236, 641, 382, 705, 204, 305]

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %% [markdown]
# To show a figure of scatter plot as follow:

# %%
plt.scatter(months, Customer_1, marker='d', color='gray', label='customer1')
plt.scatter(months, Customer_2, marker='^', color='yellow', label='customer2')
plt.xlabel('Months')
plt.ylabel('Consume of Client (KWh)')
plt.grid()
plt.show()
